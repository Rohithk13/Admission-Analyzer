# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # New Section

# %%
dataset = pd.read_csv('Admission_Predict_Ver1.1.csv')
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x = sc_x.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
from keras import initializers
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.preprocessing import StandardScaler

# %%
model = Sequential()
model.add(Dense(10,input_dim = len(x_train[0]),kernel_initializer='random_uniform', activation='sigmoid' ))
model.add(Dropout(0.2))
model.add(Dense(50,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(50,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(1, kernel_initializer='normal'))

# %%
model.compile(loss = 'mean_squared_error', optimizer= 'adam')

history = model.fit(x_train,y_train, validation_split=0.25, batch_size= 5, epochs=  100)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 1s 7ms/step - loss: 0.1815 - val_loss: 0.0211
# Epoch 2/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0591 - val_loss: 0.0450
# Epoch 3/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0453 - val_loss: 0.0230
# Epoch 4/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0336 - val_loss: 0.0220
# Epoch 5/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0345 - val_loss: 0.0247
# Epoch 6/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0260 - val_loss: 0.0258
# Epoch 7/100
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0243 - val_loss: 0.0240
# Epoch 8/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0248 - val_loss: 0.0230
# Epoch 9/100
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0336
# Epoch 10/100
# ...

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import mean_absolute_error
score = mean_absolute_error(y_test,y_pred)

# %%
print("The mean erro is = "+ str(score))

model.save('My_Model.h5')
# Out:
# The mean erro is = 0.09593399157524111

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.scatter(y_test, y_pred)
plt.title('Actual vs Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
dataset.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
fig, ax = plt.subplots()

# Create the scatter plot
ax.scatter(dataset['GRE Score'], dataset['Chance of Admit '], label='GRE Score')

# Set the title and axis labels
ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

# Show the legend
ax.legend()

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(dataset['TOEFL Score'], dataset['Chance of Admit '], label='TOEFL Score')

ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(dataset['University Rating'], dataset['Chance of Admit '], label='University Rating')

ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(dataset['SOP'], dataset['Chance of Admit '], label='SOP')

ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(dataset['LOR '], dataset['Chance of Admit '], label='LOR')

ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(dataset['CGPA'], dataset['Chance of Admit '], label='CGPA')

ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(dataset['Research'], dataset['Chance of Admit '], label='Research')

ax.set_title('Admission Chance vs Admission Factors')
ax.set_xlabel('Admission Factors')
ax.set_ylabel('Admission Chance')

ax.legend()

plt.show()
